# %%
from torch.utils.data import DataLoader
from learner import Learner
from loss import *
from dataset import *
import os
from scipy.io import loadmat, savemat
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
model = torch.load('Final_Model')

# %%
rgb_npy = np.load('DATA\\UCF-Crime\\all_rgbs\\Abuse\\Abuse001_x264.mp4.npy')
flow_npy = np.load('DATA\\UCF-Crime\\all_flows\\Abuse\\Abuse001_x264.mp4.npy')
concat_npy = np.concatenate([rgb_npy, flow_npy], axis=1)

# %%
with torch.no_grad():
    inputs = torch.from_numpy(concat_npy).cuda()
    score = model(inputs)
    score = score.cpu().detach().numpy()

# %%
plt.plot(score)
